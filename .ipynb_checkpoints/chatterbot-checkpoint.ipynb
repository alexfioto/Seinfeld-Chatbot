# %% [markdown]
# ## Seinfeld Chatbot

# %%
import pandas as pd
import numpy as np
import re
import pickle

import seaborn as sns

from nltk.tokenize import word_tokenize
import nltk

# %%
df = pd.read_csv('scripts.csv', index_col=0)

# %%
df.head()
# Out:
#   Character                                           Dialogue  EpisodeNo  \
# 0     JERRY  Do you know what this is all about? Do you kno...        1.0
# 1     JERRY  (pointing at Georges shirt) See, to me, that b...        1.0
# 2    GEORGE                                   Are you through?        1.0
# 3     JERRY             You do of course try on, when you buy?        1.0
# 4    GEORGE  Yes, it was purple, I liked it, I dont actuall...        1.0
#
#      SEID  Season
# 0  S01E01     1.0
# 1  S01E01     1.0
# 2  S01E01     1.0
# 3  S01E01     1.0
# 4  S01E01     1.0

# %%
def string_len(string):
    try:
        return len(string)
    except:
        pass

# %%
df['dialogue_len'] = df['Dialogue'].apply(string_len)

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54606 entries, 0 to 54615
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Character     54606 non-null  object
#  1   Dialogue      54606 non-null  object
#  2   EpisodeNo     54606 non-null  float64
#  3   SEID          54606 non-null  object
#  4   Season        54606 non-null  float64
#  5   dialogue_len  54606 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 2.9+ MB

# %%
# removing parenthesis
df['removed_paren_dialogue'] = df['Dialogue'].str.replace(r"\(.*\)","")

# %%
df['wordcount'] = df['removed_paren_dialogue'].apply(lambda x: len(word_tokenize(x)))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54606 entries, 0 to 54615
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Character               54606 non-null  object
#  1   Dialogue                54606 non-null  object
#  2   EpisodeNo               54606 non-null  float64
#  3   SEID                    54606 non-null  object
#  4   Season                  54606 non-null  float64
#  5   dialogue_len            54606 non-null  float64
#  6   removed_paren_dialogue  54606 non-null  object
#  7   wordcount               54606 non-null  int64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 3.7+ MB

# %%
sns.histplot(data=df, x='dialogue_len');

# %%
sns.histplot(data=df, x='wordcount');

# %% [markdown]
# ### Saving dataframe with word counts less than 25 words

# %%
df = df[df['wordcount']< 10]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30568 entries, 2 to 54610
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Character               30568 non-null  object
#  1   Dialogue                30568 non-null  object
#  2   EpisodeNo               30568 non-null  float64
#  3   SEID                    30568 non-null  object
#  4   Season                  30568 non-null  float64
#  5   dialogue_len            30568 non-null  float64
#  6   removed_paren_dialogue  30568 non-null  object
#  7   wordcount               30568 non-null  int64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 2.1+ MB

# %%
dialogue_list = list(df['removed_paren_dialogue'])

# %%
len(dialogue_list)
# Out:
# 30568

# %%
dialogue_combos = []

# %%
def make_combos(dialogue):
    dialogue_combos = []
    for i in range(len(dialogue)+ 1):
        try:
            dialogue_combos.append([dialogue[i], dialogue[i+1]])
        except:
            pass
    return dialogue_combos

# %%
combos = make_combos(dialogue_list)

# %%
combos
# Out:
# [['Are you through?', 'Oh, you dont recall?'],
#  ['Oh, you dont recall?', ' Uh, no, not at this time.'],
#  [' Uh, no, not at this time.', 'Mr. Seinfeld. Mr. Costanza.'],
#  ['Mr. Seinfeld. Mr. Costanza.', 'No, you didnt!'],
#  ['No, you didnt!', 'Ha.'],
#  ['Ha.', ' Theres no milk in here, what...'],
#  [' Theres no milk in here, what...', 'Oh, nothing happened, but it was...'],
#  ['Oh, nothing happened, but it was...', 'Yeah.'],
#  ['Yeah.', 'This is great!'],
#  ['This is great!', 'Yeah.'],
#  ['Yeah.', 'Yeah, but...'],
#  ['Yeah, but...', 'Yeah!'],
#  ['Yeah!', 'To be polite? You are insane!'],
#  ['To be polite? You are insane!', 'Yes!'],
#  ['Yes!', 'What gave it away, George?'],
#  ['What gave it away, George?', 'Uh huh.'],
#  ['Uh huh.', 'Oh you are beautiful!'],
#  ['Oh you are beautiful!', 'Id have to say, uuhh, no.'],
#  ['Id have to say, uuhh, no.', 'NO.)'],
#  ['NO.)', 'To be polite.'],
#  ['To be polite.', 'To be polite. I rest my case.'],
#  ['To be polite. I rest my case.', 'Im not gonna watch you do laundry.'],
#  ['Im not gonna watch you do laundry.', 'Come on, Im tired.'],
#  ['Come on, Im tired.', ' Right, I knew I felt something!'],
#  [' Right, I knew I felt something!',
#   'And you didnt even hear how she sounded.'],
#  ['And you didnt even hear how she sounded.', 'What?!'],
#  ['What?!', 'Laura.'],
#  ['Laura.', 'I cant believe-  WE ALREADY DISCUSSED THIS!'],
#  ['I cant believe-  WE ALREADY DISCUSSED THIS!', 'No.'],
#  ['No.', 'Yeah.'],
#  ['Yeah.', 'Maybe youre right.'],
#  ['Maybe youre right.', 'Maybe Im right? Of course Im right.'],
#  ['Maybe Im right? Of course Im right.', 'Youre gonna overdry it.'],
#  ['Youre gonna overdry it.', 'You, you cant overdry.'],
#  ['You, you cant overdry.', 'Why not?'],
#  ['Why not?', ' Any questions?'],
#  [' Any questions?', 'Look at that. Theyre done!'],
#  ['Look at that. Theyre done!', ' Yeah?'],
#  [' Yeah?', 'Are you up?'],
#  ['Are you up?', 'Yeah.  Are you done with this?'],
#  ['Yeah.  Are you done with this?', 'No.'],
#  ['No.', 'When youre done, let me know.'],
#  ['When youre done, let me know.', 'You want me to talk to her?'],
#  ['You want me to talk to her?', 'I dont think so.'],
#  ['I dont think so.', 'That close, huh?'],
#  ['That close, huh?', 'You better believe it.'],
#  ['You better believe it.', 'Hello...Oh, hi, Laura.'],
#  ['Hello...Oh, hi, Laura.', ' SLIDE! Wow!'],
#  [' SLIDE! Wow!', 'A decent hotel-room...'],
#  ['A decent hotel-room...', 'I think I was affected by the caffeine.'],
#  ['I think I was affected by the caffeine.',
#   'Hey, he really likes you, George.'],
#  ['Hey, he really likes you, George.', 'Well, thats flattering.'],
#  ['Well, thats flattering.', 'Yeah.'],
#  ['Yeah.', 'Why even give her an option?'],
#  ['Why even give her an option?', 'So what? Thats good.'],
#  ['So what? Thats good.', 'Now, how could that be good?'],
#  ['Now, how could that be good?', 'This is how you operate?'],
#  ['This is how you operate?', 'Yeah, I wish.'],
#  ['Yeah, I wish.', 'Let me just wipe the sink.'],
#  ['Let me just wipe the sink.', 'Why even give her an option for?'],
#  ['Why even give her an option for?', ' Its unbelievable.'],
#  [' Its unbelievable.', 'Yeah.'],
#  ['Yeah.', 'Hows the real estate-business?'],
#  ['Hows the real estate-business?', 'Well, I might be getting into that.'],
#  ['Well, I might be getting into that.', ' You keep me posted!'],
#  [' You keep me posted!', 'Im aware of you.  Lets go!'],
#  ['Im aware of you.  Lets go!', 'Really? How?'],
#  ['Really? How?', 'Cause its all in the greeting.'],
#  ['Cause its all in the greeting.', 'Uh-huh.'],
#  ['Uh-huh.', 'Right.'],
#  ['Right.', 'Lip area.'],
#  ['Lip area.', 'You know a hug definitely good.'],
#  ['You know a hug definitely good.', 'Hug is definitely good.'],
#  ['Hug is definitely good.', 'Sure.'],
#  ['Sure.', 'Thats so brutal, I hate that.'],
#  ['Thats so brutal, I hate that.', 'You know how they do that?'],
#  ['You know how they do that?', 'Hand sandwich.'],
#  ['Hand sandwich.', 'Right.'],
#  ['Right.', 'Guess who?'],
#  ['Guess who?', 'Hey, hey.'],
#  ['Hey, hey.', 'Heeeey!'],
#  ['Heeeey!', 'Its good to see you.'],
#  ['Its good to see you.', 'Hi.'],
#  ['Hi.', 'This is my friend George.'],
#  ['This is my friend George.', 'Hi, how nice to meet you.'],
#  ['Hi, how nice to meet you.', 'Hi, how are you?'],
#  ['Hi, how are you?', 'This is Laura.'],
#  ['This is Laura.', 'Laura, sure.'],
#  ['Laura, sure.', ' I cant believe youre here.'],
#  [' I cant believe youre here.', 'Ooh yeah, the bags, sure.'],
#  ['Ooh yeah, the bags, sure.', 'Oh, thank you.'],
#  ['Oh, thank you.', 'So uh, what do you think?'],
#  ['So uh, what do you think?', 'Uh, yeah, I think I do.'],
#  ['Uh, yeah, I think I do.', 'Really? What would you like to do?'],
#  ['Really? What would you like to do?',
#   ' Im just, Im really glad youre here.'],
#  [' Im just, Im really glad youre here.', ' Um, its for you.'],
#  [' Um, its for you.', ' Never get engaged.'],
#  [' Never get engaged.', ' Youre engaged?'],
#  [' Youre engaged?', 'Youre engaged?'],
#  ['Youre engaged?', ' Youre engaged.'],
#  [' Youre engaged.', 'Yeah, yeah, hes a great guy...'],
#  ['Yeah, yeah, hes a great guy...', 'Yeah.'],
#  ['Yeah.', 'Me too!'],
#  ['Me too!', 'Cheque.'],
#  ['Cheque.', 'Whats that one?'],
#  ['Whats that one?', 'Oh, lovely.'],
#  ['Oh, lovely.', 'Yeah.'],
#  ['Yeah.', 'What do you think their parents think?'],
#  ['What do you think their parents think?', 'Pamela? Do I know her?'],
#  ['Pamela? Do I know her?', 'Oh yeah, right...'],
#  ['Oh yeah, right...', ' No.'],
#  [' No.', ' Riverside Drive.'],
#  [' Riverside Drive.', 'Well, what is it?'],
#  ['Well, what is it?', 'What little deal?'],
#  ['What little deal?', 'Theyre coming in?'],
#  ['Theyre coming in?', 'Yeah, tomorrow.'],
#  ['Yeah, tomorrow.', 'Why does he do that?'],
#  ['Why does he do that?', 'A wedding?'],
#  ['A wedding?', 'Theres a lot of people to mock...'],
#  ['Theres a lot of people to mock...', 'All right, what the hell.'],
#  ['All right, what the hell.', 'Great!'],
#  ['Great!', 'Cmon lets go...'],
#  ['Cmon lets go...', 'Was I supposed to bring something?'],
#  ['Was I supposed to bring something?', 'You could have.'],
#  ['You could have.', 'I met her one time...'],
#  ['I met her one time...', 'It is not necessary.'],
#  ['It is not necessary.', 'What did you say then?'],
#  ['What did you say then?', 'Sssshhhhhh!!!'],
#  ['Sssshhhhhh!!!', 'Hi'],
#  ['Hi', 'Hi, Pamela, you remember Jerry.'],
#  ['Hi, Pamela, you remember Jerry.', ' Yes, we met.'],
#  [' Yes, we met.', 'Hi, happy birthday.'],
#  ['Hi, happy birthday.', 'Hi'],
#  ['Hi', 'I didnt bring anything.'],
#  ['I didnt bring anything.', 'Uh, I put you two right here.'],
#  ['Uh, I put you two right here.', 'Im in for five...'],
#  ['Im in for five...', 'Ill supply the hat.'],
#  ['Ill supply the hat.', ' Uh-oh... What do we have here?'],
#  [' Uh-oh... What do we have here?', 'How masculine.'],
#  ['How masculine.', ' Hey, this guy says he knows Bricker.'],
#  [' Hey, this guy says he knows Bricker.',
#   'Oh, you know Bricker! From where?'],
#  ['Oh, you know Bricker! From where?', ' How do you know Pamela?'],
#  [' How do you know Pamela?', 'We went to law school together.'],
#  ['We went to law school together.', ' Oh, Jerry!'],
#  [' Oh, Jerry!', ' Oh no, not now.'],
#  [' Oh no, not now.', ' This is brutal.'],
#  [' This is brutal.', ' Jerry? Are you listening to me?'],
#  [' Jerry? Are you listening to me?', 'Yes, I heard you.'],
#  ['Yes, I heard you.', ' So, youre a lawyer...'],
#  [' So, youre a lawyer...', 'Oh, that was you?'],
#  ['Oh, that was you?', 'Imagine, spelling Mom with two Os.'],
#  ['Imagine, spelling Mom with two Os.', 'Very funny! What do you do?'],
#  ['Very funny! What do you do?', 'Comedian.'],
#  ['Comedian.', 'Really? That explains it.'],
#  ['Really? That explains it.', 'Are you ready?'],
#  ['Are you ready?', 'We gotta run. Happy birthday!'],
#  ['We gotta run. Happy birthday!', 'That wasnt so bad, really.'],
#  ['That wasnt so bad, really.', 'Why? What did I do?'],
#  ['Why? What did I do?', 'I was listening!'],
#  ['I was listening!', 'Uh-huh...'],
#  ['Uh-huh...', 'Where you had, uh, wooden teeth.'],
#  ['Where you had, uh, wooden teeth.', 'So nothing! Nothing. '],
#  ['So nothing! Nothing. ', 'Hey!'],
#  ['Hey!', 'Ah, there he is!'],
#  ['Ah, there he is!', 'Tomorrow well go to a hotel.'],
#  ['Tomorrow well go to a hotel.', 'Ma, will you stop?'],
#  ['Ma, will you stop?', 'I dont care. Im sleeping next door.'],
#  ['I dont care. Im sleeping next door.', 'Your friend Kramer doesnt mind?'],
#  ['Your friend Kramer doesnt mind?', 'No, hes making a bouillabaisse.'],
#  ['No, hes making a bouillabaisse.', 'Depends on the firm.'],
#  ['Depends on the firm.', 'Whats the matter? You need a lawyer?'],
#  ['Whats the matter? You need a lawyer?', 'Why not?'],
#  ['Why not?', 'Because its complicated. Theres some tension there.'],
#  ['Because its complicated. Theres some tension there.',
#   'He used to go with her.'],
#  ['He used to go with her.', 'Which one is she?'],
#  ['Which one is she?', 'Oh yeah, very alert. Warm person.'],
#  ['Oh yeah, very alert. Warm person.', 'Oh yeah, shes great.'],
#  ['Oh yeah, shes great.', 'So, how come nothing materialized there?'],
#  ['So, how come nothing materialized there?', 'I know what it was.'],
#  ['I know what it was.', 'You dont know what it was.'],
#  ['You dont know what it was.', 'So, what was it?'],
#  ['So, what was it?', 'Oh, well...'],
#  ['Oh, well...', 'Oh, she is, she absolutely is.'],
#  ['Oh, she is, she absolutely is.', 'I know, I know...'],
#  ['I know, I know...', ' So whore you looking for, Sophia Loren?'],
#  [' So whore you looking for, Sophia Loren?',
#   'Thats got nothin to do with it.'],
#  ['Thats got nothin to do with it.', 'How about Loni Anderson?'],
#  ['How about Loni Anderson?', 'Where do you get Loni Anderson?'],
#  ['Where do you get Loni Anderson?', 'Why, whats wrong with Loni Anderson?'],
#  ['Why, whats wrong with Loni Anderson?',
#   'I like Elaine more than Loni Anderson.'],
#  ['I like Elaine more than Loni Anderson.', 'And this other ones the one?'],
#  ['And this other ones the one?', 'I dunno, maybe...'],
#  ['I dunno, maybe...', 'So ask Elaine there for her number.'],
#  ['So ask Elaine there for her number.', 'Were friends.'],
#  ['Were friends.', 'Oh yeah.'],
#  ['Oh yeah.', 'Well, go up to the office.'],
#  ['Well, go up to the office.', 'Up to her office?'],
#  ['Up to her office?', 'I guess.'],
#  ['I guess.', 'You mean stakeout the lobby?'],
#  ['You mean stakeout the lobby?', 'He pretends he bumped into her!'],
#  ['He pretends he bumped into her!', 'What does she look like?'],
#  ['What does she look like?', 'I dunno. Hard to say.'],
#  ['I dunno. Hard to say.', 'What actress does she remind you of?'],
#  ['What actress does she remind you of?', 'Loni Anderson.'],
#  ['Loni Anderson.', 'Loni Anderson?!'],
#  ['Loni Anderson?!', 'Im a little nervous.'],
#  ['Im a little nervous.', 'Yeah, me too...'],
#  ['Yeah, me too...', 'What do you do?'],
#  ['What do you do?', 'Im an architect.'],
#  ['Im an architect.', 'Youre an architect?'],
#  ['Youre an architect?', 'Im not?'],
#  ['Im not?', 'I dont see architecture comin from you.'],
#  ['I dont see architecture comin from you.',
#   ' I suppose you could be an architect.'],
#  [' I suppose you could be an architect.', 'What is his name?'],
#  ['What is his name?', 'Bert Harbinson? It sounds made up.'],
#  ['Bert Harbinson? It sounds made up.', 'Art Cor...'],
#  ['Art Cor...', '...velay.'],
#  ['...velay.', 'Corvelay?'],
#  ['Corvelay?', 'Yeah, right.'],
#  ['Yeah, right.', 'Well, what does he do?'],
#  ['Well, what does he do?', 'Hes an importer.'],
#  ['Hes an importer.', 'Just imports, no exports?'],
#  ['Just imports, no exports?', ' Elaine ever call you back?'],
#  [' Elaine ever call you back?', 'No, I guess shes still mad.'],
#  ['No, I guess shes still mad.', 'Vandelay!'],
#  ['Vandelay!', 'Corvelay!'],
#  ['Corvelay!', 'Sure! Hi!'],
#  ['Sure! Hi!', 'Uh, this is George.  Im sorry...'],
#  ['Uh, this is George.  Im sorry...', 'Vanessa.'],
#  ['Vanessa.', 'Nice to meet you.'],
#  ['Nice to meet you.', 'Yeah, Art Vandelay.'],
#  ['Yeah, Art Vandelay.', 'Really? Which company?'],
#  ['Really? Which company?', ' I dont know. Hes an importer.'],
#  [' I dont know. Hes an importer.', 'Importer?'],
#  ['Importer?', '...And exporter.'],
#  ['...And exporter.', 'Hes an importer/exporter.'],
#  ['Hes an importer/exporter.', ' Im, uh, Im an architect.'],
#  [' Im, uh, Im an architect.', 'Really. What do you design?'],
#  ['Really. What do you design?', 'Uh, railroads, uh...'],
#  ['Uh, railroads, uh...', 'I thought engineers do that.'],
#  ['I thought engineers do that.', 'They can...'],
#  ['They can...', 'Oh, that guy was your cousin! '],
#  ['Oh, that guy was your cousin! ', 'Yeah, and that woman was your...'],
#  ['Yeah, and that woman was your...', 'Friend!'],
#  ['Friend!', 'Ill just, uh, get a paper...'],
#  ['Ill just, uh, get a paper...', 'Almost exclusively...'],
#  ['Almost exclusively...', ' Ma, will you go already?'],
#  [' Ma, will you go already?', 'Bum bum bum bum...'],
#  ['Bum bum bum bum...', 'What are you doing?!'],
#  ['What are you doing?!', 'Wait, I just want to see something.'],
#  ['Wait, I just want to see something.',
#   'You cant look in there, were playing!'],
#  ['You cant look in there, were playing!', 'Hi.'],
#  ['Hi.', 'Hi.'],
#  ['Hi.', ' Good evening, Mr. Kramer!'],
#  [' Good evening, Mr. Kramer!', 'Hey Morty!  Salad dressing?'],
#  ['Hey Morty!  Salad dressing?', 'Look.'],
#  ['Look.', 'Quo. Is that a word?'],
#  ['Quo. Is that a word?', 'Maybe!'],
#  ['Maybe!', 'Will you challenge it?'],
#  ['Will you challenge it?', 'Quo? Thats not a word.'],
#  ['Quo? Thats not a word.', ' Youre such a stickler...'],
#  [' Youre such a stickler...', 'She said what?'],
#  ['She said what?', 'Just what I said, here.'],
#  ['Just what I said, here.', 'She knows what?'],
#  ['She knows what?', 'So, how did she find out?'],
#  ['So, how did she find out?', 'Whatever I wrote down.'],
#  ['Whatever I wrote down.', 'Who am I, Rich Little?'],
#  ['Who am I, Rich Little?', 'Yeah, but now Im nervous.'],
#  ['Yeah, but now Im nervous.', 'Oh, stop it.'],
#  ['Oh, stop it.', 'Quone?'],
#  ['Quone?', '...30...31...'],
#  ['...30...31...', '...32...'],
#  ['...32...', 'I am challenging.'],
#  ['I am challenging.', 'Quone. To quone something.'],
#  ['Quone. To quone something.', 'Uh-huh.'],
#  ['Uh-huh.', 'Im not playing with you anymore.'],
#  ['Im not playing with you anymore.', 'Quones not a word.'],
#  ['Quones not a word.', ' Why did you make me put that down?'],
#  [' Why did you make me put that down?',
#   'You must have quite a time down there.'],
#  ['You must have quite a time down there.', 'We got plenty of time.'],
#  ['We got plenty of time.', 'Yeah, yeah...'],
#  ['Yeah, yeah...', 'Yeah, Uncle Mac, you mentioned it.'],
#  ['Yeah, Uncle Mac, you mentioned it.', 'Its based on all my experiences!'],
#  ['Its based on all my experiences!', 'Thats perfect.'],
#  ['Thats perfect.', 'Oh no, lets do it now.'],
#  ['Oh no, lets do it now.', 'Okay.'],
#  ['Okay.', 'Jerry, were you goin with us?'],
#  ['Jerry, were you goin with us?', 'No, Im gonna take my car.'],
#  ['No, Im gonna take my car.', 'Oh, bye. Good to see you.'],
#  ['Oh, bye. Good to see you.', 'Oh, we didnt meet.'],
#  ['Oh, we didnt meet.', ' Levine.'],
#  [' Levine.', 'Yeah, obviously.'],
#  ['Yeah, obviously.', 'Couldnt agree more.'],
#  ['Couldnt agree more.', 'Good.'],
#  ['Good.', 'Good.'],
#  ['Good.', 'Good.'],
#  ['Good.', 'Great!'],
#  ['Great!', 'Great? Where do you get great?'],
#  ['Great? Where do you get great?', '...Guys?'],
#  ['...Guys?', 'Yeah.'],
#  ['Yeah.', 'Uh-huh. Yeah. So, anybody specific?'],
#  ['Uh-huh. Yeah. So, anybody specific?', 'No. A general guy.'],
#  ['No. A general guy.', 'Oh really? Elaine Marie Benes...'],
#  ['Oh really? Elaine Marie Benes...', 'No, thats great! Thats terrific!'],
#  ['No, thats great! Thats terrific!', 'No, we just met...'],
#  ['No, we just met...', 'Hmmm, I dont think so.'],
#  ['Hmmm, I dont think so.', 'Wall street.'],
#  ['Wall street.', 'And he happens to be pretty good lookin.'],
#  ['And he happens to be pretty good lookin.', ' All right, sir.'],
#  [' All right, sir.', 'And... hes hilarious.'],
#  ['And... hes hilarious.', 'I staked out his health club.'],
#  ['I staked out his health club.', ' I am...the master packer.'],
#  [' I am...the master packer.', ' Yeah, right, youre the master packer.'],
#  [' Yeah, right, youre the master packer.', ' Scuse me, master packer...'],
#  [' Scuse me, master packer...', 'Yes.'],
#  ['Yes.', 'Just gimme your keys.'],
#  ['Just gimme your keys.', 'All right, sir.  George?'],
#  ['All right, sir.  George?', ' Yeah.'],
#  [' Yeah.', 'Okay, this is quite a place.'],
#  ['Okay, this is quite a place.', 'Theres more. The refrigerator.'],
#  ['Theres more. The refrigerator.', 'Ill eat out.'],
#  ['Ill eat out.', ' Ready?'],
#  [' Ready?', 'Yeah, one sec.'],
#  ['Yeah, one sec.', 'Hey, Elaine.'],
#  ['Hey, Elaine.', 'Hi.'],
#  ['Hi.', 'Coming to the airport with us?'],
#  ['Coming to the airport with us?', 'Oh, the actress-waitress?'],
#  ['Oh, the actress-waitress?', 'So just kick her out.'],
#  ['So just kick her out.', 'Im not looking.'],
#  ['Im not looking.', 'Yeah, whats it like?'],
#  ['Yeah, whats it like?', 'How much?'],
#  ['How much?', 'Really? Why?'],
#  ['Really? Why?', 'Cause then I could move in here.'],
#  ['Cause then I could move in here.', 'Ohhhh...'],
#  ['Ohhhh...', 'Its time you got outta here anyway.'],
#  ['Its time you got outta here anyway.', 'Elaine.  ELAINE!'],
#  ['Elaine.  ELAINE!', 'What?'],
#  ['What?', 'They were stolen.'],
#  ['They were stolen.', 'Stolen? When?'],
#  ['Stolen? When?', 'Stolen?'],
#  ['Stolen?', ' Someone left the door open.'],
#  [' Someone left the door open.', ' You left the door open?!'],
#  [' You left the door open?!', ' The door.'],
#  [' The door.', 'The door? You left the door open?'],
#  ['The door? You left the door open?', 'Yeah, and?'],
#  ['Yeah, and?', 'So the door was wide open?'],
#  ['So the door was wide open?', 'Wide open!'],
#  ['Wide open!', ' And where were you?'],
#  [' And where were you?', 'No.'],
#  ['No.', ' How can you not have insurance?'],
#  [' How can you not have insurance?', ' I made a mistake.'],
#  [' I made a mistake.', 'These things happen.'],
#  ['These things happen.', 'Im human.'],
#  ['Im human.', 'In your way.'],
#  ['In your way.', 'Answering machine.'],
#  ['Answering machine.', 'What do you mean?'],
#  ['What do you mean?', 'Its a joke.'],
#  ['Its a joke.', 'You ever find anything?'],
#  ['You ever find anything?', 'No.'],
#  ['No.', 'Well, thanks anyway.'],
#  ['Well, thanks anyway.', 'You bet.'],
#  ['You bet.', 'I didnt get that joke either.'],
#  ['I didnt get that joke either.', 'Again?'],
#  ['Again?', 'Yeah, tell im George.'],
#  ['Yeah, tell im George.', ' You would still wanna move in here?'],
#  [' You would still wanna move in here?',
#   ' Is that uh, other apartment still available?'],
#  [' Is that uh, other apartment still available?', 'They deliver it.'],
#  ['They deliver it.', 'They deliver wood?'],
#  ['They deliver wood?', 'Yeah.'],
#  ['Yeah.', 'What do you tip a wood guy?'],
#  ['What do you tip a wood guy?', 'I didnt know there was a fireplace.'],
#  ['I didnt know there was a fireplace.', 'Would I have to get a gardener?'],
#  ['Would I have to get a gardener?', 'Yeah, you can get a gardener.'],
#  ['Yeah, you can get a gardener.', 'You tip him?'],
#  ['You tip him?', 'You can.'],
#  ['You can.', ' You dont tip a gardener!'],
#  [' You dont tip a gardener!', 'You can tip a gardener.'],
#  ['You can tip a gardener.', 'You dont need a gardener.'],
#  ['You dont need a gardener.', 'Jerry, you can barbecue back here.'],
#  ['Jerry, you can barbecue back here.', 'They deliver the coal?'],
#  ['They deliver the coal?', 'Oh, then I gotta tip him.'],
#  ['Oh, then I gotta tip him.', 'I dont have any plants.'],
#  ['I dont have any plants.', 'I have plants. '],
#  ['I have plants. ', 'Its your decision.'],
#  ['Its your decision.', ' isnt that incredible!'],
#  [' isnt that incredible!', ' Congratulations.'],
#  [' Congratulations.', 'What about the couch?'],
#  ['What about the couch?', 'What?'],
#  ['What?', 'Yeah!'],
#  ['Yeah!', 'For this couch?!'],
#  ['For this couch?!', 'Yeah?'],
#  ['Yeah?', ' Yeah, its George.'],
#  [' Yeah, its George.', 'Fifty dollars?'],
#  ['Fifty dollars?', 'Uh-huh.'],
#  ['Uh-huh.', 'Thank you very much.'],
#  ['Thank you very much.', 'Thank you very much.'],
#  ['Thank you very much.', 'Hey, whats goin on?'],
#  ['Hey, whats goin on?', 'I just bought Jerrys couch for fifty dollars.'],
#  ['I just bought Jerrys couch for fifty dollars.', 'Why?'],
#  ['Why?', 'You could take it? You want it?'],
#  ['You could take it? You want it?', 'So you do want it.'],
#  ['So you do want it.', 'You just said you wanted it!'],
#  ['You just said you wanted it!', 'So take it.'],
#  ['So take it.', 'How can I take it?'],
#  ['How can I take it?', 'How can I take it?'],
#  ['How can I take it?', 'Its your apartment!'],
#  ['Its your apartment!', 'Yes, but I am not taking it.'],
#  ['Yes, but I am not taking it.', 'I...am not taking it.'],
#  ['I...am not taking it.', 'Well, whaddaya wanna do here?'],
#  ['Well, whaddaya wanna do here?', 'I, I dont know.'],
#  ['I, I dont know.', 'Do you wanna flip a coin?'],
#  ['Do you wanna flip a coin?', 'Who flips? Youll flip, Ill call.'],
#  ['Who flips? Youll flip, Ill call.', 'Im good.'],
#  ['Im good.', 'No catchin.'],
#  ['No catchin.', 'No no.'],
#  ['No no.', 'Flip it.'],
#  ['Flip it.', 'Heads!'],
#  ['Heads!', 'Tails!'],
#  ['Tails!', 'So what?'],
#  ['So what?', 'You didnt call no interference!'],
#  ['You didnt call no interference!', 'I dont believe this.'],
#  ['I dont believe this.', 'Id better not.'],
#  ['Id better not.', 'Odds.'],
#  ['Odds.', 'I want evens.'],
#  ['I want evens.', 'Good.'],
#  ['Good.', 'You got odds.'],
#  ['You got odds.', 'You got evens.'],
#  ['You got evens.', 'Right, ready?'],
#  ['Right, ready?', 'For the apartment.'],
#  ['For the apartment.', 'Once, twice, three, shoot!'],
#  ['Once, twice, three, shoot!', 'Mine!'],
#  ['Mine!', 'Once, twice, three, shoot!'],
#  ['Once, twice, three, shoot!', 'Mine!'],
#  ['Mine!', 'Once, twice, three, shoot!'],
#  ['Once, twice, three, shoot!', 'Mine!'],
#  ['Mine!', 'Once, twice, three, shoot!'],
#  ['Once, twice, three, shoot!', 'Congratulations...congratulations.'],
#  ['Congratulations...congratulations.', 'Thanks.'],
#  ['Thanks.', 'Yeah.'],
#  ['Yeah.', 'Hard to imagine.'],
#  ['Hard to imagine.', '..you know, very casually,'],
#  ['..you know, very casually,', 'Right.'],
#  ['Right.', 'So what did he say?'],
#  ['So what did he say?', 'What stuff?'],
#  ['What stuff?', 'Ooh,  case closed!'],
#  ['Ooh,  case closed!', 'Okay, starting...NOW!'],
#  ['Okay, starting...NOW!', 'Yeah!'],
#  ['Yeah!', 'What?!'],
#  ['What?!', 'How can I live there?'],
#  ['How can I live there?', 'Why not?!'],
#  ['Why not?!', 'Oh, get outta here.'],
#  ['Oh, get outta here.', 'I wont mope.'],
#  ['I wont mope.', 'No, impossible! Its your apartment.'],
#  ['No, impossible! Its your apartment.', 'You found the place.'],
#  ['You found the place.', 'You won the choose.'],
#  ['You won the choose.', 'Well, me neither.'],
#  ['Well, me neither.', 'Definitely?'],
#  ['Definitely?', 'Definitely.'],
#  ['Definitely.', 'What apartment?'],
#  ['What apartment?', 'Whats the rent?'],
#  ['Whats the rent?', 'She wanted to thank us for the apartment.'],
#  ['She wanted to thank us for the apartment.',
#   'If only the coin hadnt hit the table.'],
#  ['If only the coin hadnt hit the table.',
#   'The table is interference, you know it!'],
#  ['The table is interference, you know it!', 'It is not!'],
#  ['It is not!', 'It is too!'],
#  ['It is too!', 'My roommate starts rehearsal tonight on Carousel.'],
#  ['My roommate starts rehearsal tonight on Carousel.', 'Hi.'],
#  ['Hi.', 'Hi, Carol.'],
#  ['Hi, Carol.', 'Its a dream.'],
#  ['Its a dream.', 'Were really glad for you.'],
#  ['Were really glad for you.', 'Couldnt be happier.'],
#  ['Couldnt be happier.', 'Its wonderful.'],
#  ['Its wonderful.', 'Diane, Diane, come here.'],
#  ['Diane, Diane, come here.', 'Well, it was nice to meet you.'],
#  ['Well, it was nice to meet you.', 'Nice meeting you.'],
#  ['Nice meeting you.', 'Whats the rent?'],
#  ['Whats the rent?', 'I dont think you did anything wrong.'],
#  ['I dont think you did anything wrong.', 'We can only thank God for that.'],
#  ['We can only thank God for that.', 'Youre imagining this. Really.'],
#  ['Youre imagining this. Really.', 'Oh, no. No no no no.'],
#  ['Oh, no. No no no no.', 'What floss? When?'],
#  ['What floss? When?', 'Ah, mint.'],
#  ['Ah, mint.', 'And youre sure the floss was the catalyst?'],
#  ['And youre sure the floss was the catalyst?', 'Yes, I am.'],
#  ['Yes, I am.', 'What? You dont like this?'],
#  ['What? You dont like this?', ' Who is it?'],
#  [' Who is it?', 'Take it.'],
#  ['Take it.', 'Who is it?'],
#  ['Who is it?', 'Its for you.'],
#  ['Its for you.', 'Maybe I didnt want to talk to him.'],
#  ['Maybe I didnt want to talk to him.', 'Well, why not?'],
#  ['Well, why not?', 'Were going. Thats next Wednesday.'],
#  ['Were going. Thats next Wednesday.', 'Oh. Who is this guy?'],
#  ['Oh. Who is this guy?', 'Can you conduct your business elsewhere?'],
#  ['Can you conduct your business elsewhere?', 'Just break up with him?'],
#  ['Just break up with him?', 'Absolutely. You just tell him the truth.'],
#  ['Absolutely. You just tell him the truth.', 'The Truth.'],
#  ['The Truth.', 'Yeah.'],
#  ['Yeah.', ' Im gonna do it in Farsi.'],
#  [' Im gonna do it in Farsi.', 'Do you think I need a haircut?'],
#  ['Do you think I need a haircut?', 'Are you ready?'],
#  ['Are you ready?', ' I hate it.'],
#  [' I hate it.', 'I think its real turkey.'],
#  ['I think its real turkey.', 'Is there a real bird in the back?'],
#  ['Is there a real bird in the back?', 'No, theres not bird but-'],
#  ['No, theres not bird but-', 'How can you talk to someone like that?'],
#  ['How can you talk to someone like that?', 'Howard Metro.'],
#  ['Howard Metro.', 'What?'],
#  ['What?', 'This friendship Its not working.'],
#  ['This friendship Its not working.',
#   'Not working? What are you talking about?'],
#  ['Not working? What are you talking about?',
#   'Were just not suited to be friends.'],
#  ['Were just not suited to be friends.', 'How can you say that?'],
#  ['How can you say that?', 'No, its not that.'],
#  ['No, its not that.', 'Oh, come on. Thats not true.'],
#  ['Oh, come on. Thats not true.', 'I know, I know.'],
#  ['I know, I know.', 'I mean, youre my best friend.'],
#  ['I mean, youre my best friend.',
#   'Best friend- Ive never been to your apartment.'],
#  ['Best friend- Ive never been to your apartment.', 'Didnt mean what?'],
#  ['Didnt mean what?', 'Tonight?'],
#  ['Tonight?', 'Do you really want me to go?'],
#  ['Do you really want me to go?', ' Yes.'],
#  [' Yes.', 'Next Wednesday.'],
#  ['Next Wednesday.', 'Where is that waitress?  Hey!'],
#  ['Where is that waitress?  Hey!', '...she calls me up at my office'],
#  ['...she calls me up at my office', 'Yeah.'],
#  ['Yeah.', ' she says, We have to talk.'],
#  [' she says, We have to talk.', 'That, or Whos bra is this?'],
#  ['That, or Whos bra is this?', 'That is worse.'],
#  ['That is worse.', 'Really.'],
#  ['Really.', 'Hm. You ate.'],
#  ['Hm. You ate.', 'Have you ever had their egg salad?'],
#  ['Have you ever had their egg salad?', 'It is unbelievable.'],
#  ['It is unbelievable.', 'How much could you possibly have in there?'],
#  ['How much could you possibly have in there?',
#   ' Thats funny. Youre a funny guy.'],
#  [' Thats funny. Youre a funny guy.', 'Cmon, move up.'],
#  ['Cmon, move up.', 'Oh great, Ewings hurt.'],
#  ['Oh great, Ewings hurt.', 'A couple of days at the most but...'],
#  ['A couple of days at the most but...', 'Geez.'],
#  ['Geez.', 'Oh, God.'],
#  ['Oh, God.', 'What about it?'],
#  ['What about it?', 'What?'],
#  ['What?', 'I gave your ticket to Horneck.'],
#  ['I gave your ticket to Horneck.', ' You what?!'],
#  [' You what?!', 'Why did you give him my ticket for?'],
#  ['Why did you give him my ticket for?',
#   'You didnt see him. It was horrible.'],
#  ['You didnt see him. It was horrible.', 'I had to do it.'],
#  ['I had to do it.', '...thirty-two, thirty-three-'],
#  ['...thirty-two, thirty-three-', 'George.'],
#  ['George.', 'Not now.'],
#  ['Not now.', 'Could you stop the counting?'],
#  ['Could you stop the counting?', 'Nnnnnnngaaa!'],
#  ['Nnnnnnngaaa!', 'What?!'],
#  ['What?!', 'Oh geeeee.  Go, go!'],
#  ['Oh geeeee.  Go, go!', 'I- no, I dont want to go.'],
#  ['I- no, I dont want to go.', 'He was really crying?'],
#  ['He was really crying?', 'George, the man wept.'],
#  ['George, the man wept.', 'Its all supervised.'],
#  ['Its all supervised.', 'Oh, well...'],
#  ['Oh, well...', 'All of it. You want to invest?'],
#  ['All of it. You want to invest?', 'Thats you.'],
#  ['Thats you.', 'Im just saying..Alright.'],
#  ['Im just saying..Alright.', 'Okay.'],
#  ['Okay.', 'Trapezoid?'],
#  ['Trapezoid?', 'Okay.'],
#  ['Okay.', 'Want to go get something to eat?'],
#  ['Want to go get something to eat?', 'Where do you want to go?'],
#  ['Where do you want to go?', 'I dont care, Im not hungry.'],
#  ['I dont care, Im not hungry.', 'We could talk.'],
#  ['We could talk.', 'Ill go if I dont have to talk.'],
#  ['Ill go if I dont have to talk.', 'Then well just sit there.'],
#  ['Then well just sit there.', 'Okay, just hand that over, please.'],
#  ['Okay, just hand that over, please.', 'Oh, what is this?'],
#  ['Oh, what is this?', 'I got some for you.'],
#  ['I got some for you.', 'I dont need any more.'],
#  ['I dont need any more.', ' Very funny.'],
#  [' Very funny.', 'What can I do?'],
#  ['What can I do?', 'Deal with it. Be a man!'],
#  ['Deal with it. Be a man!', 'Couple of tough monkeys.'],
#  ['Couple of tough monkeys.', 'Game?'],
#  ['Game?', 'Wait. How does Horneck know you?'],
#  ['Wait. How does Horneck know you?', 'This is too much.'],
#  ['This is too much.', 'Wait, what pizza place idea?'],
#  ['Wait, what pizza place idea?', 'Oh, no.'],
#  ['Oh, no.', 'You get to make your own pie!'],
#  ['You get to make your own pie!', 'Yea.'],
#  ['Yea.', ' Kramer.'],
#  [' Kramer.', 'Yeah.'],
#  ['Yeah.', 'Perfect.'],
#  ['Perfect.', 'Hey.'],
#  ['Hey.', 'Okay, who wants meatloaf?'],
#  ['Okay, who wants meatloaf?', 'No thanks.'],
#  ['No thanks.', ' Its gonna be hot in a minute.'],
#  [' Its gonna be hot in a minute.', 'Oh, we finished early.'],
#  ['Oh, we finished early.', 'Elaine Benes, this is Joel Horneck.'],
#  ['Elaine Benes, this is Joel Horneck.', 'Hi.'],
#  ['Hi.', 'Were still friends.'],
#  ['Were still friends.', 'Right. I forgot about choir.'],
#  ['Right. I forgot about choir.', 'You really should.'],
#  ['You really should.', 'Well, lets just take a look here.'],
#  ['Well, lets just take a look here.',
#   'I never heard him say anything really funny.'],
#  ['I never heard him say anything really funny.',
#   'I dont know. But he aint funny.'],
#  ['I dont know. But he aint funny.', 'No problem.'],
#  ['No problem.', 'I dropped a grape.'],
#  ['I dropped a grape.', 'Pardon?'],
#  ['Pardon?', 'Robert.'],
#  ['Robert.', 'Guys with cats... I dont know.'],
#  ['Guys with cats... I dont know.', 'Vanessa.'],
#  ['Vanessa.', 'Youre getting what?'],
#  ['Youre getting what?', 'A stock.'],
#  ['A stock.', 'What stock?'],
#  ['What stock?', 'Did you ever meet my friend, Simons?'],
#  ['Did you ever meet my friend, Simons?', 'Maybe.'],
#  ['Maybe.', 'How highs it suppose to go?'],
#  ['How highs it suppose to go?', 'Boy... I dont know.'],
#  ['Boy... I dont know.', 'What kind of company is it?'],
#  ['What kind of company is it?', 'Televising opera?'],
#  ['Televising opera?', 'Some sort of electronic thingy.'],
#  ['Some sort of electronic thingy.', 'Boy...'],
#  ['Boy...', 'What if I lose it?'],
#  ['What if I lose it?', 'All right. Twenty-five hundred.'],
#  ['All right. Twenty-five hundred.', 'Thats it.'],
#  ['Thats it.', 'Yeah, can I take your order?'],
#  ['Yeah, can I take your order?', ' Check the raiser.'],
#  [' Check the raiser.', 'Tuna?'],
#  ['Tuna?', 'Oh, the dolphin thing?'],
#  ['Oh, the dolphin thing?', 'Theyre dying in the nets.'],
#  ['Theyre dying in the nets.', 'Okay.  What about you?'],
#  ['Okay.  What about you?', 'Ill have the tuna.'],
#  ['Ill have the tuna.', 'Why didnt you do something?'],
#  ['Why didnt you do something?', 'No puffs. Just flakes.'],
#  ['No puffs. Just flakes.', 'Have you thought any more about that trip?'],
#  ['Have you thought any more about that trip?',
#   'Yeah, Ive been thinking about it.'],
#  ['Yeah, Ive been thinking about it.',
#   'Really? Could we go fishing up there?'],
#  ['Really? Could we go fishing up there?', 'They have marlin in Vermont?'],
#  ['They have marlin in Vermont?', 'Oh, big fighting marlin. '],
#  ['Oh, big fighting marlin. ', 'Is that my paper?'],
#  ['Is that my paper?', 'Bad news, my friend.'],
#  ['Bad news, my friend.', 'What? What news?'],
#  ['What? What news?', 'Sendrax.'],
#  ['Sendrax.', 'Oh, cmon! Its down again?!'],
#  ['Oh, cmon! Its down again?!', 'Two and a half points.'],
#  ['Two and a half points.', 'Hey, I told you.'],
#  ['Hey, I told you.', ' Yeah, you told me.'],
#  [' Yeah, you told me.', ' George, whats going on?!'],
#  [' George, whats going on?!', 'Sell it, just say Im selling!'],
#  ['Sell it, just say Im selling!',
#   'Roll-out tie dispenser? What was that one?'],
#  ['Roll-out tie dispenser? What was that one?', 'Okay...'],
#  ['Okay...', ' Oh No!'],
#  [' Oh No!', 'Youre gone all right.'],
#  ['Youre gone all right.', 'What friends?'],
#  ['What friends?', 'So you dont know whats wrong with him?'],
#  ['So you dont know whats wrong with him?', 'Well, this is it. Im selling.'],
#  ['Well, this is it. Im selling.', 'Just give it a little more time.'],
#  ['Just give it a little more time.', 'Where?'],
#  ['Where?', 'To the hospital.'],
#  ['To the hospital.', 'The hospital?'],
#  ['The hospital?', 'Maybe hes resting.'],
#  ['Maybe hes resting.', 'Who goes to the hospital to rest?'],
#  ['Who goes to the hospital to rest?', 'What are you, a doctor?'],
#  ['What are you, a doctor?', 'All right.'],
#  ['All right.', ' May I help you?'],
#  [' May I help you?', 'When did you bring it in?'],
#  ['When did you bring it in?', 'You got a receipt?'],
#  ['You got a receipt?', 'I cant find the receipt.'],
#  ['I cant find the receipt.', 'You should get the receipt.'],
#  ['You should get the receipt.', 'Maybe you asked for it to be washed.'],
#  ['Maybe you asked for it to be washed.', 'No! Dry-cleaned.'],
#  ['No! Dry-cleaned.', ' I shrunk it.'],
#  [' I shrunk it.', 'Bless you.'],
#  ['Bless you.', 'So what are you gonna do?'],
#  ['So what are you gonna do?', 'Im no cat killer.'],
#  ['Im no cat killer.', 'He actually went to the hospital?'],
#  ['He actually went to the hospital?', 'Yeah.'],
#  ['Yeah.', 'Oh man, hes nuts.'],
#  ['Oh man, hes nuts.', 'How much are you down altogether?'],
#  ['How much are you down altogether?',
#   'I dont know.. fifteen hundred dollars.'],
#  ['I dont know.. fifteen hundred dollars.', 'Wow.'],
#  ['Wow.', 'I really dont need to look.'],
#  ['I really dont need to look.', 'Fifteen seconds.'],
#  ['Fifteen seconds.', 'You told him you knew Simons?'],
#  ['You told him you knew Simons?', 'Didnt work, huh?'],
#  ['Didnt work, huh?', ' Not quite.'],
#  [' Not quite.', 'I know. You mentioned it.'],
#  ['I know. You mentioned it.', 'Oh yeah, right.'],
#  ['Oh yeah, right.', 'No, its got a little battery.'],
#  ['No, its got a little battery.', 'Well, thats good.'],
#  ['Well, thats good.', 'No, its okay.'],
#  ['No, its okay.', 'Not especially.'],
#  ['Not especially.', 'What can we do? Its raining.'],
#  ['What can we do? Its raining.', 'Oh, youve never heard of it.'],
#  ['Oh, youve never heard of it.', 'No, what? What kind is it?'],
#  ['No, what? What kind is it?', 'I cant tell you.'],
#  ['I cant tell you.', 'I told you not to sell.'],
#  ['I told you not to sell.', 'You did not tell me not to sell.'],
#  ['You did not tell me not to sell.',
#   'I said the market fluctuates. Remember?'],
#  ['I said the market fluctuates. Remember?', "Thats probably why we're-"],
#  ["Thats probably why we're-", 'What?'],
#  ['What?', 'Forget it.'],
#  ['Forget it.', 'No, what? Thats probably why..'],
#  ['No, what? Thats probably why..', 'Im good, thanks.'],
#  ['Im good, thanks.', 'Im kinda full.'],
#  ['Im kinda full.', 'So dont finish it.'],
#  ['So dont finish it.', 'I dont like to discuss figures.'],
#  ['I dont like to discuss figures.', 'How much?'],
#  ['How much?', 'So, Wilkinsons out of the hospital now?'],
#  ['So, Wilkinsons out of the hospital now?', 'Oh god.'],
#  ['Oh god.', 'Is that still from the cats?'],
#  ['Is that still from the cats?', 'No, I just have a cold.'],
#  ['No, I just have a cold.', 'So, what ever happened with that?'],
#  ['So, what ever happened with that?', 'I gave him an ultimatum.'],
#  ['I gave him an ultimatum.', 'He chose the cats?'],
#  ['He chose the cats?', 'Theyre very clean animals.'],
#  ['Theyre very clean animals.', 'Superman can go back in time?'],
#  ['Superman can go back in time?', 'We went over that.'],
#  ['We went over that.', 'A robot butcher?'],
#  ['A robot butcher?', 'She cant kill me right?'],
#  ['She cant kill me right?', 'No, of course not.'],
#  ['No, of course not.', 'People break up all the time.'],
#  ['People break up all the time.', 'Everyday.'],
#  ['Everyday.', 'You tried.'],
#  ['You tried.', 'Did you tell her you loved her?'],
#  ['Did you tell her you loved her?', 'Youre a human being.'],
#  ['Youre a human being.', 'Youre too nice a guy.'],
#  ['Youre too nice a guy.', 'Youre flesh and blood.'],
#  ['Youre flesh and blood.', 'I told you when I met her.'],
#  ['I told you when I met her.', 'My back is killing me.'],
#  ['My back is killing me.', 'Oh yeah, everybodys guy is the best.'],
#  ['Oh yeah, everybodys guy is the best.', 'Hi.'],
#  ['Hi.', 'Hi.'],
#  ['Hi.', 'Hey, what are you doing?'],
#  ['Hey, what are you doing?', 'Im letting you in.'],
#  ['Im letting you in.', 'No, you wont.'],
#  ['No, you wont.', 'Okay.'],
#  ['Okay.', 'Why cant you sit in the middle?'],
#  ['Why cant you sit in the middle?', 'Is it that obvious?'],
#  ['Is it that obvious?', 'Hello, Jerry.'],
#  ['Hello, Jerry.', 'Hello.'],
#  ['Hello.', 'Did you get a haircut?'],
#  ['Did you get a haircut?', 'Really?'],
#  ['Really?', 'Yes.'],
#  ['Yes.', 'You would do that?'],
#  ['You would do that?', 'If I was a different person.'],
#  ['If I was a different person.', ' Come on up.'],
#  [' Come on up.', 'Taste this.'],
#  ['Taste this.', 'No, I just had a sandwich.'],
#  ['No, I just had a sandwich.', 'No, taste it. Taste it.'],
#  ['No, taste it. Taste it.', 'I dont want cantaloupe now.'],
#  ['I dont want cantaloupe now.',
#   'Youve never had cantaloupe like this before...'],
#  ['Youve never had cantaloupe like this before...',
#   'I only eat cantaloupe at certain times...'],
#  ['I only eat cantaloupe at certain times...',
#   '...Jerry. This is great cantaloupe.'],
#  ['...Jerry. This is great cantaloupe.', '...all right!'],
#  ['...all right!', 'Uh-huh. Its good?'],
#  ['Uh-huh. Its good?', 'Its very good.'],
#  ['Its very good.', 'Good, huh?'],
#  ['Good, huh?', 'Good.'],
#  ['Good.', 'I got it at Joes.'],
#  ['I got it at Joes.', 'Uh-huh.'],
#  ['Uh-huh.', 'Its too far.'],
#  ['Its too far.', 'You did it? What happened?'],
#  ['You did it? What happened?', 'Uh-huh...'],
#  ['Uh-huh...', 'I liked Marlene. Whats her number?'],
#  ['I liked Marlene. Whats her number?', ' Could you stop that smacking?'],
#  [' Could you stop that smacking?', 'Oh no, thank you.'],
#  ['Oh no, thank you.', 'Its the best cantaloupe I ever had.'],
#  ['Its the best cantaloupe I ever had.', 'So, go get them.'],
#  ['So, go get them.', 'Well, yeah.'],
#  ['Well, yeah.', 'What do you need them for?'],
#  ['What do you need them for?', 'I dont know. Theyre books.'],
#  ['I dont know. Theyre books.', 'Theyre my books.'],
#  ['Theyre my books.', 'So whatd you do?'],
#  ['So whatd you do?', 'No.'],
#  ['No.', 'I dont know how this happened.'],
#  ['I dont know how this happened.', 'Jerry, its not my fault.'],
#  ['Jerry, its not my fault.', 'I dunno sometimes...'],
#  ['I dunno sometimes...', 'What trying to get off the phone?'],
#  ['What trying to get off the phone?', 'Yeah. Yes, she is.'],
#  ['Yeah. Yes, she is.', 'Mr. Costanza?'],
#  ['Mr. Costanza?', 'Yeah.'],
#  ['Yeah.', 'The doctor will see you now.'],
#  ['The doctor will see you now.', ' Oh, hello, Doctor.'],
#  [' Oh, hello, Doctor.', 'So, how was it?'],
#  ['So, how was it?', 'Well, its a first visit.'],
#  ['Well, its a first visit.', 'You cant do that.'],
#  ['You cant do that.', 'Why not?'],
#  ['Why not?', 'Are you feeling weird?'],
#  ['Are you feeling weird?', 'No, Im fine.'],
#  ['No, Im fine.', 'Nothing really happened.'],
#  ['Nothing really happened.', 'Yeah, I know.'],
#  ['Yeah, I know.', 'We just kissed a little. People kiss.'],
#  ['We just kissed a little. People kiss.', 'Yeah.'],
#  ['Yeah.', 'Well... night.'],
#  ['Well... night.', ' Good night.'],
#  [' Good night.', 'Hey.'],
#  ['Hey.', 'Hey.'],
#  ['Hey.', 'All right.'],
#  ['All right.', 'Hips! See, its all hips.'],
#  ['Hips! See, its all hips.', 'Uh-huh.'],
#  ['Uh-huh.', 'That is out there.'],
#  ['That is out there.', 'Joes?'],
#  ['Joes?', 'No, supermarket.'],
#  ['No, supermarket.', 'Well, is it good?'],
#  ['Well, is it good?', 'Its uh okay.'],
#  ['Its uh okay.', 'Let me taste it.'],
#  ['Let me taste it.', 'Im not taking it back.'],
#  ['Im not taking it back.', 'I dont care about it.'],
#  ['I dont care about it.', 'All right. Take it back.'],
#  ['All right. Take it back.', 'Leave a message, Ill call you back.'],
#  ['Leave a message, Ill call you back.', 'Well?'],
#  ['Well?', 'Marlene.'],
#  ['Marlene.', ' Oh. Oh, Marlene...'],
#  [' Oh. Oh, Marlene...', 'Does George know?'],
#  ['Does George know?', 'No, hed go nuts.'],
#  ['No, hed go nuts.', 'Yeah, no kidding.'],
#  ['Yeah, no kidding.', 'Whoa, psychosexual.'],
#  ['Whoa, psychosexual.', 'Its partially you, yeah.'],
#  ['Its partially you, yeah.', 'Well, he cant kill me, right?'],
#  ['Well, he cant kill me, right?', 'Youre a human being.'],
#  ['Youre a human being.', 'Youre flesh and blood.'],
#  ['Youre flesh and blood.', 'Im a nice guy.'],
#  ['Im a nice guy.', 'Hi.'],
#  ['Hi.', ' Oh, my little airplane lamp.'],
#  [' Oh, my little airplane lamp.', 'Unless youre married to a dictator.'],
#  ['Unless youre married to a dictator.', 'Nope. No good.'],
#  ['Nope. No good.', 'Well, Im taking this back.'],
#  ['Well, Im taking this back.', 'Really? That guy who stopped saying hello?'],
#  ['Really? That guy who stopped saying hello?', 'Yes.'],
#  ['Yes.', 'You talked to him?'],
#  ['You talked to him?', 'Right.'],
#  ['Right.', 'You said "you little phony"?'],
#  ['You said "you little phony"?', 'This is amazing.'],
#  ['This is amazing.', 'This cantaloupe stinks.'],
#  ['This cantaloupe stinks.', ' I dont care.'],
#  [' I dont care.', 'Youre kidding.'],
#  ['Youre kidding.', 'No, I dont care.'],
#  ['No, I dont care.', 'You mean that?'],
#  ['You mean that?', 'Absolutely.'],
#  ['Absolutely.', 'You dont care?'],
#  ['You dont care?', 'No.'],
#  ['No.', 'How could you not care?'],
#  ['How could you not care?', 'I thought youd be upset.'],
#  ['I thought youd be upset.', 'I know. I know.'],
#  ['I know. I know.', ' You paid that crook?!'],
#  [' You paid that crook?!', 'I had to.'],
#  ['I had to.', 'It was embarrassing to me.'],
#  ['It was embarrassing to me.', ' What can happen?!'],
#  [' What can happen?!', 'Really? I thought...'],
#  ['Really? I thought...', 'I know, Im sorry.'],
#  ['I know, Im sorry.', 'Of course I want to talk about it.'],
#  ['Of course I want to talk about it.',
#   'Tuesday night? What happened Tuesday night?'],
#  ['Tuesday night? What happened Tuesday night?', 'I saw your act.'],
#  ['I saw your act.', 'Youre a cashier!'],
#  ['Youre a cashier!', 'I heard the material.'],
#  ['I heard the material.', 'Are you getting that?'],
#  ['Are you getting that?', 'I thought you were getting it.'],
#  ['I thought you were getting it.', 'Should I pick up?'],
#  ['Should I pick up?', 'You want me to get that?'],
#  ['You want me to get that?', 'Ill get it!'],
#  ['Ill get it!', 'Ill get it!'],
#  ['Ill get it!', 'Hello?... Hello?'],
#  ['Hello?... Hello?', 'Hi.'],
#  ['Hi.', 'Hi.'],
#  ['Hi.', 'So, howd you do?'],
#  ['So, howd you do?', 'This is your greatest moment? A game?'],
#  ['This is your greatest moment? A game?', 'But its their 50th anniversary.'],
#  ['But its their 50th anniversary.', 'So bring her.'],
#  ['So bring her.', 'How come he gets to leave?'],
#  ['How come he gets to leave?', 'And its always about Jeffrey, right?'],
#  ['And its always about Jeffrey, right?', 'Morty, are you coming in?'],
#  ['Morty, are you coming in?', ' Hey, howd you do?'],
#  [' Hey, howd you do?', 'Yeah!'],
#  ['Yeah!', ' What is this about?'],
#  [' What is this about?', 'What are you doing?'],
#  ['What are you doing?', 'Levels.'],
#  ['Levels.', 'Levels?'],
#  ['Levels?', 'You drew up plans for this?'],
#  ['You drew up plans for this?', 'No no. Its all in my head.'],
#  ['No no. Its all in my head.', 'Oh, Ill be comfortable.'],
#  ['Oh, Ill be comfortable.', 'When do you intend to do this?'],
#  ['When do you intend to do this?', 'Youre doing this yourself?'],
#  ['Youre doing this yourself?', 'Hey, thats some big job.'],
#  ['Hey, thats some big job.', 'I, dont see it happening.'],
#  ['I, dont see it happening.', 'Seriously?'],
#  ['Seriously?', 'Ill give you a year.'],
#  ['Ill give you a year.', 'No no no. End of the month.'],
#  ['No no no. End of the month.', 'Its a bet.'],
#  ['Its a bet.', ' Seriously, do you wanna switch chairs?'],
#  [' Seriously, do you wanna switch chairs?', 'No, no. Im fine.'],
#  ['No, no. Im fine.', 'Jerry, are you listening to this?'],
#  ['Jerry, are you listening to this?', 'Yeah, Uncle Leo.'],
#  ['Yeah, Uncle Leo.', 'No, for the walking tours.'],
#  ['No, for the walking tours.', 'Mickey Mantle?'],
#  ['Mickey Mantle?', ' These peas are great!'],
#  [' These peas are great!',
#   ' These peas are bursting with country fresh flavor.'],
#  [' These peas are bursting with country fresh flavor.',
#   'Mmm... phenomenal peas.'],
#  ['Mmm... phenomenal peas.', 'Are you ready for dessert?'],
#  ['Are you ready for dessert?', ' Youre going?'],
#  [' Youre going?', 'Cant dance?'],
#  ['Cant dance?', 'Hes kidding, Manya.'],
#  ['Hes kidding, Manya.', 'Is that a joke?'],
#  ['Is that a joke?', 'So, did you hear Claires getting married?'],
#  ['So, did you hear Claires getting married?', 'Yeah, yeah..'],
#  ['Yeah, yeah..', 'Horses? Theyre like big riding dogs.'],
#  ['Horses? Theyre like big riding dogs.', ' I had a pony.'],
#  [' I had a pony.', 'Should we have coffee? Whos having coffee?'],
#  ['Should we have coffee? Whos having coffee?', 'You! You said so!'],
#  ['You! You said so!', 'Thats it! I had enough!'],
#  ['Thats it! I had enough!', 'Ill drive you to the airport.'],
#  ['Ill drive you to the airport.', 'No, were taking a cab.'],
#  ['No, were taking a cab.', 'Dont be ridiculous. It was a misunderstanding.'],
#  ['Dont be ridiculous. It was a misunderstanding.', 'Maybe I will.'],
#  ['Maybe I will.', 'Need any help with those?'],
#  ['Need any help with those?', ' Really? What a shock.'],
#  [' Really? What a shock.', 'Goodbye, Jerry.'],
#  ['Goodbye, Jerry.', 'Take care.'],
#  ['Take care.', 'Well call you.'],
#  ['Well call you.', 'Bye, Jer.'],
#  ['Bye, Jer.', 'Bye, Dad. Take it easy.'],
#  ['Bye, Dad. Take it easy.', 'Bye, Mr. Kramer.'],
#  ['Bye, Mr. Kramer.', 'Yeah. So long, Morty.'],
#  ['Yeah. So long, Morty.', 'So, when do I get my dinner?'],
#  ['So, when do I get my dinner?', 'And it could be done.'],
#  ['And it could be done.', 'I dont want the levels!'],
#  ['I dont want the levels!', 'Who did you talk to?'],
#  ['Who did you talk to?', 'Uncle Leo.'],
#  ['Uncle Leo.', 'And whens the funeral?'],
#  ['And whens the funeral?', 'What?'],
#  ['What?', 'What? Nothing.'],
#  ['What? Nothing.', 'You dont think that I killed her?'],
#  ['You dont think that I killed her?',
#   'You know what the flight backll cost us?'],
#  ['You know what the flight backll cost us?', 'The funerals Wednesday.'],
#  ['The funerals Wednesday.', 'Wednesday? What, what Wednesday?'],
#  ['Wednesday? What, what Wednesday?', 'Two o clock, Wednesday.'],
#  ['Two o clock, Wednesday.', 'Ah'],
#  ['Ah', 'What?'],
#  ['What?', 'I didnt even know the woman.'],
#  ['I didnt even know the woman.', 'So dont go.'],
#  ['So dont go.', 'Jerry, no ones forcing you.'],
#  ['Jerry, no ones forcing you.', 'I got my sport jacket.'],
#  ['I got my sport jacket.', 'Youre not wearing that to a funeral.'],
#  ['Youre not wearing that to a funeral.', 'Whats wrong with it?'],
#  ['Whats wrong with it?', 'It looks ridiculous.'],
#  ['It looks ridiculous.', 'I dont know what to do.'],
#  ['I dont know what to do.', 'Two Forty-Five.'],
#  ['Two Forty-Five.', 'And what times the funeral?'],
#  ['And what times the funeral?', 'Two o clock.'],
#  ['Two o clock.', 'How long does a funeral take?'],
#  ['How long does a funeral take?', 'So you cant do both?'],
#  ['So you cant do both?', 'How can you even consider not going?'],
#  ['How can you even consider not going?', ' Whos going to play left field?'],
#  [' Whos going to play left field?', 'Bender.'],
#  ['Bender.', 'Phoenix? Whats happening with his appartment?'],
#  ['Phoenix? Whats happening with his appartment?',
#   'Well, the games starting just about now.'],
#  ['Well, the games starting just about now.', 'Yeah.'],
#  ['Yeah.', 'Oh, me too.'],
#  ['Oh, me too.', 'So, I understand youre moving to Phoenix?'],
#  ['So, I understand youre moving to Phoenix?',
#   'Although they say its a dry heat.'],
#  ['Although they say its a dry heat.', 'Oh, Jeffrey.'],
#  ['Oh, Jeffrey.', 'You know Jeffery?'],
#  ['You know Jeffery?', 'Its raining.'],
#  ['Its raining.', 'I cant. Ill get in trouble.'],
#  ['I cant. Ill get in trouble.', 'Oh, for Gods sake!'],
#  ['Oh, for Gods sake!', 'Its never happened to me before.'],
#  ['Its never happened to me before.', 'I thought there were two outs.'],
#  ['I thought there were two outs.', ' What about Sharon Besser?'],
#  [' What about Sharon Besser?',
#   'Oh, well, of course. Nineteen-seventy-three.'],
#  ['Oh, well, of course. Nineteen-seventy-three.',
#   'Makes you wonder, though, doesnt it?'],
#  ['Makes you wonder, though, doesnt it?', 'Wonder about what?'],
#  ['Wonder about what?', 'You know...  the spirit world.'],
#  ['You know...  the spirit world.', 'I never saw anyone play like that.'],
#  ['I never saw anyone play like that.', 'But I went to the funeral.'],
#  ['But I went to the funeral.', 'Not necessarily.'],
#  ['Not necessarily.', 'I think Ive seen enough.'],
#  ['I think Ive seen enough.', ' Her father wrote that.'],
#  [' Her father wrote that.', 'Alton Benes is your father?'],
#  ['Alton Benes is your father?', 'Yeah.'],
#  ['Yeah.', 'I always felt he deserved a wider audience.'],
#  ['I always felt he deserved a wider audience.',
#   'Im not so sure he wants one.'],
#  ['Im not so sure he wants one.', 'I guess Im coming. I mean...'],
#  ['I guess Im coming. I mean...', 'No, Ill go. Im going.'],
#  ['No, Ill go. Im going.', 'So, thats why were not together anymore.'],
#  ['So, thats why were not together anymore.', 'What is this?'],
#  ['What is this?', 'Try it on.'],
#  ['Try it on.', 'Wow, this is soft suede.'],
#  ['Wow, this is soft suede.', 'How much is it?'],
#  ['How much is it?', ' Oh my God.'],
#  [' Oh my God.', 'Bad?  Very bad?'],
#  ['Bad?  Very bad?', 'You have no idea.'],
#  ['You have no idea.', 'I have some idea.'],
#  ['I have some idea.', 'No idea.'],
#  ['No idea.', 'Ive got a ballpark.'],
#  ['Ive got a ballpark.', 'Let me see that.  That is high.'],
#  ['Let me see that.  That is high.', 'It looks wonderful on you.'],
#  ['It looks wonderful on you.', 'Hey.'],
#  ['Hey.', 'Hey. New jacket?'],
#  ['Hey. New jacket?', 'What do you think?'],
#  ['What do you think?', 'Its beautiful.'],
#  ['Its beautiful.', 'Is it me?'],
#  ['Is it me?', 'Thats definitely you.'],
#  ['Thats definitely you.', 'Really?'],
#  ['Really?', 'I paid what it costs.'],
#  ...]

# %%
# Building empty lists to hold sentences
input_docs = []
target_docs = []
# Building empty vocabulary sets
input_tokens = set()
target_tokens = set()

for line in combos[:25000]:
  # Input and target sentences are separated by tabs
  input_doc, target_doc = line[0], line[1]
  # Appending each input sentence to input_docs
  input_docs.append(input_doc)
  # Splitting words from punctuation  
  target_doc = " ".join(re.findall(r"[\w']+|[^\s\w]", target_doc))
  # Redefine target_doc below 
  # and append it to target_docs:
  target_doc = '<START> ' + target_doc + ' <END>'
  target_docs.append(target_doc)
  
  # Now we split up each sentence into words
  # and add each unique word to our vocabulary set
  for token in re.findall(r"[\w']+|[^\s\w]", input_doc):
    # Add your code here:
    if token not in input_tokens:
      input_tokens.add(token)
    
  for token in target_doc.split():
    # And here:
    if token not in target_tokens:
      target_tokens.add(token)

# %%
input_tokens = sorted(list(input_tokens))
target_tokens = sorted(list(target_tokens))

# Create num_encoder_tokens and num_decoder_tokens:
num_encoder_tokens = len(input_tokens)
num_decoder_tokens = len(target_tokens)

# Finding the maximum 
max_encoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", input_doc)) for input_doc in input_docs])
max_decoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", target_doc)) for target_doc in target_docs])

# %%
# Creating four dictionaries

input_features_dict = dict(
    [(token, i) for i, token in enumerate(input_tokens)])
target_features_dict = dict(
    [(token, i) for i, token in enumerate(target_tokens)])

reverse_input_features_dict = dict(
    (i, token) for token, i in input_features_dict.items())
reverse_target_features_dict = dict(
    (i, token) for token, i in target_features_dict.items())

# %%
# Creating empty matricies

encoder_input_data = np.zeros(
    (len(input_docs), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

# %%
print(f'Encoder Input Data Shape: {encoder_input_data.shape}')
print(f'Decoder Input Data Shape: {decoder_input_data.shape}')
print(f'Decoder Target Data Shape: {decoder_target_data.shape}')
# Out:
# Encoder Input Data Shape: (25000, 27, 8223)
# Decoder Input Data Shape: (25000, 33, 8225)
# Decoder Target Data Shape: (25000, 33, 8225)

# %%
for line, (input_doc, target_doc) in enumerate(zip(input_docs, target_docs)):

  for timestep, token in enumerate(re.findall(r"[\w']+|[^\s\w]", input_doc)):
    # Assign 1. for the current line, timestep, & word
    # in encoder_input_data:
    encoder_input_data[line, timestep, input_features_dict[token]] = 1.
    # add in conditional for handling unknown tokens (when token is not in input features dict)

  for timestep, token in enumerate(target_doc.split()):

    decoder_input_data[line, timestep, target_features_dict[token]] = 1.
    if timestep > 0:

      decoder_target_data[line, timestep - 1, target_features_dict[token]] = 1.

# %%
list(enumerate(zip(input_docs, target_docs)))[:10]
# Out:
# [(0, ('Are you through?', '<START> Oh , you dont recall ? <END>')),
#  (1, ('Oh, you dont recall?', '<START> Uh , no , not at this time . <END>')),
#  (2,
#   (' Uh, no, not at this time.',
#    '<START> Mr . Seinfeld . Mr . Costanza . <END>')),
#  (3, ('Mr. Seinfeld. Mr. Costanza.', '<START> No , you didnt ! <END>')),
#  (4, ('No, you didnt!', '<START> Ha . <END>')),
#  (5, ('Ha.', '<START> Theres no milk in here , what . . . <END>')),
#  (6,
#   (' Theres no milk in here, what...',
#    '<START> Oh , nothing happened , but it was . . . <END>')),
#  (7, ('Oh, nothing happened, but it was...', '<START> Yeah . <END>')),
#  (8, ('Yeah.', '<START> This is great ! <END>')),
#  (9, ('This is great!', '<START> Yeah . <END>'))]

# %%
list(enumerate(re.findall(r"[\w]+|[^\s\s]", input_doc)))
# Out:
# [(0, 'Yea'),
#  (1, 'you'),
#  (2, "'"),
#  (3, 're'),
#  (4, 'leaving'),
#  (5, 'at'),
#  (6, 'three'),
#  (7, 'o'),
#  (8, "'"),
#  (9, 'clock'),
#  (10, '.')]

# %%
list(enumerate(word_tokenize(input_doc)))
# Out:
# [(0, 'Yea'),
#  (1, 'you'),
#  (2, "'re"),
#  (3, 'leaving'),
#  (4, 'at'),
#  (5, 'three'),
#  (6, "o'clock"),
#  (7, '.')]

# %%
#from preprocessing import num_encoder_tokens, num_decoder_tokens, decoder_target_data, encoder_input_data, decoder_input_data, decoder_target_data, max_encoder_seq_length, max_decoder_seq_length
from tensorflow import keras
# Add Dense to the imported layers
from tensorflow.keras.layers import Input, LSTM, Dense, Masking
from tensorflow.keras.models import Model
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# Choose dimensionality
dimensionality = 256

# Choose the batch size
# and number of epochs:
batch_size = 200
epochs = 100

# Encoder training setup
encoder_inputs = Input(shape=(None, num_encoder_tokens))

encoder_lstm = LSTM(dimensionality, return_state=True)
encoder_outputs, state_hidden, state_cell = encoder_lstm(encoder_inputs)
encoder_states = [state_hidden, state_cell]

# Decoder training setup:
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(dimensionality, return_sequences=True, return_state=True)
decoder_outputs, decoder_state_hidden, decoder_state_cell = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %% [markdown]
# ## The code below was used to train my training model. Implemented in Google Colab

# %%
# Building the training model:
training_model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model:
training_model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'], sample_weight_mode='temporal')

# # print("Training the model:\n")
# # Train the model:
training_model.fit([encoder_input_data, decoder_input_data], decoder_target_data, batch_size = batch_size, epochs = epochs, validation_split = 0.2)

training_model.save('training_model.h5')
# Out:
# Epoch 1/100
# 100/100 [==============================] - 357s 4s/step - loss: 0.9698 - accuracy: 0.0346 - val_loss: 0.9183 - val_accuracy: 0.0359
# Epoch 2/100
# 100/100 [==============================] - 374s 4s/step - loss: 0.8894 - accuracy: 0.0389 - val_loss: 0.9057 - val_accuracy: 0.0383
# Epoch 3/100
# 100/100 [==============================] - 380s 4s/step - loss: 0.8588 - accuracy: 0.0463 - val_loss: 0.8675 - val_accuracy: 0.0515
# Epoch 4/100
# 100/100 [==============================] - 384s 4s/step - loss: 0.8232 - accuracy: 0.0535 - val_loss: 0.8398 - val_accuracy: 0.0545
# Epoch 5/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.7965 - accuracy: 0.0573 - val_loss: 0.8228 - val_accuracy: 0.0579
# Epoch 6/100
# 100/100 [==============================] - 386s 4s/step - loss: 0.7748 - accuracy: 0.0601 - val_loss: 0.8056 - val_accuracy: 0.0597
# Epoch 7/100
# 100/100 [==============================] - 385s 4s/step - loss: 0.7565 - accuracy: 0.0639 - val_loss: 0.7946 - val_accuracy: 0.0608
# Epoch 8/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.7403 - accuracy: 0.0694 - val_loss: 0.7876 - val_accuracy: 0.0620
# Epoch 9/100
# 100/100 [==============================] - 387s 4s/step - loss: 0.7263 - accuracy: 0.0717 - val_loss: 0.7804 - val_accuracy: 0.0677
# Epoch 10/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.7135 - accuracy: 0.0739 - val_loss: 0.7718 - val_accuracy: 0.0780
# Epoch 11/100
# 100/100 [==============================] - 386s 4s/step - loss: 0.7018 - accuracy: 0.0817 - val_loss: 0.7651 - val_accuracy: 0.0699
# Epoch 12/100
# 100/100 [==============================] - 387s 4s/step - loss: 0.6912 - accuracy: 0.0769 - val_loss: 0.7639 - val_accuracy: 0.0716
# Epoch 13/100
# 100/100 [==============================] - 387s 4s/step - loss: 0.6818 - accuracy: 0.0777 - val_loss: 0.7579 - val_accuracy: 0.0704
# Epoch 14/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.6724 - accuracy: 0.0806 - val_loss: 0.7559 - val_accuracy: 0.0833
# Epoch 15/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.6636 - accuracy: 0.0854 - val_loss: 0.7559 - val_accuracy: 0.0796
# Epoch 16/100
# 100/100 [==============================] - 387s 4s/step - loss: 0.6554 - accuracy: 0.0829 - val_loss: 0.7504 - val_accuracy: 0.0781
# Epoch 17/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.6474 - accuracy: 0.0915 - val_loss: 0.7550 - val_accuracy: 0.0685
# Epoch 18/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.6398 - accuracy: 0.0927 - val_loss: 0.7495 - val_accuracy: 0.0861
# Epoch 19/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.6318 - accuracy: 0.1012 - val_loss: 0.7488 - val_accuracy: 0.1650
# Epoch 20/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.6244 - accuracy: 0.1301 - val_loss: 0.7470 - val_accuracy: 0.1002
# Epoch 21/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.6171 - accuracy: 0.1062 - val_loss: 0.7457 - val_accuracy: 0.1524
# Epoch 22/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.6097 - accuracy: 0.1253 - val_loss: 0.7492 - val_accuracy: 0.2201
# Epoch 23/100
# 100/100 [==============================] - 387s 4s/step - loss: 0.6024 - accuracy: 0.1750 - val_loss: 0.7512 - val_accuracy: 0.1069
# Epoch 24/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.5956 - accuracy: 0.1964 - val_loss: 0.7501 - val_accuracy: 0.3859
# Epoch 25/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.5886 - accuracy: 0.1782 - val_loss: 0.7523 - val_accuracy: 0.1991
# Epoch 26/100
# 100/100 [==============================] - 387s 4s/step - loss: 0.5820 - accuracy: 0.1835 - val_loss: 0.7490 - val_accuracy: 0.1370
# Epoch 27/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.5746 - accuracy: 0.1829 - val_loss: 0.7523 - val_accuracy: 0.2204
# Epoch 28/100
# 100/100 [==============================] - 387s 4s/step - loss: 0.5681 - accuracy: 0.1950 - val_loss: 0.7544 - val_accuracy: 0.1536
# Epoch 29/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.5616 - accuracy: 0.2230 - val_loss: 0.7549 - val_accuracy: 0.1594
# Epoch 30/100
# 100/100 [==============================] - 385s 4s/step - loss: 0.5549 - accuracy: 0.1923 - val_loss: 0.7553 - val_accuracy: 0.2052
# Epoch 31/100
# 100/100 [==============================] - 386s 4s/step - loss: 0.5486 - accuracy: 0.2021 - val_loss: 0.7590 - val_accuracy: 0.1523
# Epoch 32/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.5423 - accuracy: 0.2165 - val_loss: 0.7580 - val_accuracy: 0.1465
# Epoch 33/100
# 100/100 [==============================] - 386s 4s/step - loss: 0.5361 - accuracy: 0.1858 - val_loss: 0.7648 - val_accuracy: 0.1479
# Epoch 34/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.5299 - accuracy: 0.1841 - val_loss: 0.7654 - val_accuracy: 0.1264
# Epoch 35/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.5237 - accuracy: 0.2415 - val_loss: 0.7654 - val_accuracy: 0.1841
# Epoch 36/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.5175 - accuracy: 0.2643 - val_loss: 0.7639 - val_accuracy: 0.1650
# Epoch 37/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.5114 - accuracy: 0.2409 - val_loss: 0.7684 - val_accuracy: 0.2668
# Epoch 38/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.5051 - accuracy: 0.2885 - val_loss: 0.7722 - val_accuracy: 0.2826
# Epoch 39/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.4990 - accuracy: 0.2581 - val_loss: 0.7751 - val_accuracy: 0.2184
# Epoch 40/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.4928 - accuracy: 0.2489 - val_loss: 0.7785 - val_accuracy: 0.2658
# Epoch 41/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.4869 - accuracy: 0.2880 - val_loss: 0.7802 - val_accuracy: 0.2867
# Epoch 42/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.4810 - accuracy: 0.2661 - val_loss: 0.7836 - val_accuracy: 0.2415
# Epoch 43/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.4817 - accuracy: 0.2601 - val_loss: 0.7816 - val_accuracy: 0.2817
# Epoch 44/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.4711 - accuracy: 0.2821 - val_loss: 0.7843 - val_accuracy: 0.2417
# Epoch 45/100
# 100/100 [==============================] - 392s 4s/step - loss: 0.4644 - accuracy: 0.2664 - val_loss: 0.7891 - val_accuracy: 0.1910
# Epoch 46/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.4591 - accuracy: 0.2422 - val_loss: 0.7922 - val_accuracy: 0.1765
# Epoch 47/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.4533 - accuracy: 0.2350 - val_loss: 0.7995 - val_accuracy: 0.2270
# Epoch 48/100
# 100/100 [==============================] - 386s 4s/step - loss: 0.4473 - accuracy: 0.2016 - val_loss: 0.7965 - val_accuracy: 0.1484
# Epoch 49/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.4420 - accuracy: 0.2019 - val_loss: 0.8074 - val_accuracy: 0.1731
# Epoch 50/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.4369 - accuracy: 0.2024 - val_loss: 0.8024 - val_accuracy: 0.1485
# Epoch 51/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.4311 - accuracy: 0.2045 - val_loss: 0.8058 - val_accuracy: 0.1484
# Epoch 52/100
# 100/100 [==============================] - 386s 4s/step - loss: 0.4258 - accuracy: 0.2127 - val_loss: 0.8126 - val_accuracy: 0.2197
# Epoch 53/100
# 100/100 [==============================] - 387s 4s/step - loss: 0.4213 - accuracy: 0.2140 - val_loss: 0.8124 - val_accuracy: 0.1863
# Epoch 54/100
# 100/100 [==============================] - 391s 4s/step - loss: 0.4163 - accuracy: 0.1939 - val_loss: 0.8189 - val_accuracy: 0.1431
# Epoch 55/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.4110 - accuracy: 0.2017 - val_loss: 0.8203 - val_accuracy: 0.1575
# Epoch 56/100
# 100/100 [==============================] - 392s 4s/step - loss: 0.4056 - accuracy: 0.2126 - val_loss: 0.8223 - val_accuracy: 0.1816
# Epoch 57/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.4012 - accuracy: 0.2168 - val_loss: 0.8262 - val_accuracy: 0.1530
# Epoch 58/100
# 100/100 [==============================] - 387s 4s/step - loss: 0.3964 - accuracy: 0.2041 - val_loss: 0.8339 - val_accuracy: 0.1598
# Epoch 59/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.3913 - accuracy: 0.2151 - val_loss: 0.8312 - val_accuracy: 0.1705
# Epoch 60/100
# 100/100 [==============================] - 387s 4s/step - loss: 0.3869 - accuracy: 0.2072 - val_loss: 0.8331 - val_accuracy: 0.1489
# Epoch 61/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.3815 - accuracy: 0.2196 - val_loss: 0.8345 - val_accuracy: 0.1817
# Epoch 62/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.3776 - accuracy: 0.2127 - val_loss: 0.8436 - val_accuracy: 0.1654
# Epoch 63/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.3724 - accuracy: 0.2180 - val_loss: 0.8524 - val_accuracy: 0.1480
# Epoch 64/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.3686 - accuracy: 0.2273 - val_loss: 0.8531 - val_accuracy: 0.1841
# Epoch 65/100
# 100/100 [==============================] - 391s 4s/step - loss: 0.3638 - accuracy: 0.2429 - val_loss: 0.8524 - val_accuracy: 0.1693
# Epoch 66/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.3596 - accuracy: 0.2240 - val_loss: 0.8534 - val_accuracy: 0.1708
# Epoch 67/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.3549 - accuracy: 0.2167 - val_loss: 0.8585 - val_accuracy: 0.1716
# Epoch 68/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.3511 - accuracy: 0.2277 - val_loss: 0.8570 - val_accuracy: 0.1536
# Epoch 69/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.3470 - accuracy: 0.2194 - val_loss: 0.8700 - val_accuracy: 0.1652
# Epoch 70/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.3427 - accuracy: 0.2371 - val_loss: 0.8759 - val_accuracy: 0.1546
# Epoch 71/100
# 100/100 [==============================] - 387s 4s/step - loss: 0.3384 - accuracy: 0.2353 - val_loss: 0.8715 - val_accuracy: 0.1723
# Epoch 72/100
# 100/100 [==============================] - 387s 4s/step - loss: 0.3347 - accuracy: 0.2281 - val_loss: 0.8729 - val_accuracy: 0.1854
# Epoch 73/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.3304 - accuracy: 0.2382 - val_loss: 0.8778 - val_accuracy: 0.1735
# Epoch 74/100
# 100/100 [==============================] - 392s 4s/step - loss: 0.3262 - accuracy: 0.2524 - val_loss: 0.8787 - val_accuracy: 0.1650
# Epoch 75/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.3232 - accuracy: 0.2549 - val_loss: 0.8833 - val_accuracy: 0.1835
# Epoch 76/100
# 100/100 [==============================] - 391s 4s/step - loss: 0.3189 - accuracy: 0.2525 - val_loss: 0.8810 - val_accuracy: 0.1916
# Epoch 77/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.3151 - accuracy: 0.2652 - val_loss: 0.8912 - val_accuracy: 0.2009
# Epoch 78/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.3117 - accuracy: 0.2756 - val_loss: 0.8888 - val_accuracy: 0.1798
# Epoch 79/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.3080 - accuracy: 0.2641 - val_loss: 0.8965 - val_accuracy: 0.1906
# Epoch 80/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.3046 - accuracy: 0.2686 - val_loss: 0.8964 - val_accuracy: 0.1838
# Epoch 81/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.3008 - accuracy: 0.2491 - val_loss: 0.9077 - val_accuracy: 0.2001
# Epoch 82/100
# 100/100 [==============================] - 391s 4s/step - loss: 0.2974 - accuracy: 0.2750 - val_loss: 0.9008 - val_accuracy: 0.2140
# Epoch 83/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.2939 - accuracy: 0.2888 - val_loss: 0.9101 - val_accuracy: 0.2013
# Epoch 84/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.2910 - accuracy: 0.2783 - val_loss: 0.9130 - val_accuracy: 0.1820
# Epoch 85/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.2876 - accuracy: 0.2789 - val_loss: 0.9089 - val_accuracy: 0.2261
# Epoch 86/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.2833 - accuracy: 0.2984 - val_loss: 0.9160 - val_accuracy: 0.2135
# Epoch 87/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.2806 - accuracy: 0.3044 - val_loss: 0.9217 - val_accuracy: 0.2238
# Epoch 88/100
# 100/100 [==============================] - 391s 4s/step - loss: 0.2772 - accuracy: 0.2951 - val_loss: 0.9144 - val_accuracy: 0.2477
# Epoch 89/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.2739 - accuracy: 0.3324 - val_loss: 0.9271 - val_accuracy: 0.2170
# Epoch 90/100
# 100/100 [==============================] - 388s 4s/step - loss: 0.2705 - accuracy: 0.3117 - val_loss: 0.9213 - val_accuracy: 0.2480
# Epoch 91/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.2677 - accuracy: 0.3473 - val_loss: 0.9278 - val_accuracy: 0.2662
# Epoch 92/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.2642 - accuracy: 0.3353 - val_loss: 0.9341 - val_accuracy: 0.2632
# Epoch 93/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.2614 - accuracy: 0.3359 - val_loss: 0.9343 - val_accuracy: 0.2587
# Epoch 94/100
# 100/100 [==============================] - 390s 4s/step - loss: 0.2582 - accuracy: 0.3316 - val_loss: 0.9399 - val_accuracy: 0.2731
# Epoch 95/100
# 100/100 [==============================] - 389s 4s/step - loss: 0.2553 - accuracy: 0.3382 - val_loss: 0.9419 - val_accuracy: 0.2486
# Epoch 96/100
# 100/100 [==============================] - 392s 4s/step - loss: 0.2520 - accuracy: 0.3378 - val_loss: 0.9426 - val_accuracy: 0.2510
# Epoch 97/100
# 100/100 [==============================] - 392s 4s/step - loss: 0.2489 - accuracy: 0.3293 - val_loss: 0.9442 - val_accuracy: 0.2640
# Epoch 98/100
# 100/100 [==============================] - 393s 4s/step - loss: 0.2461 - accuracy: 0.3316 - val_loss: 0.9493 - val_accuracy: 0.2208
# Epoch 99/100
# 100/100 [==============================] - 406s 4s/step - loss: 0.2431 - accuracy: 0.3331 - val_loss: 0.9492 - val_accuracy: 0.2426
# Epoch 100/100
# 100/100 [==============================] - 394s 4s/step - loss: 0.2402 - accuracy: 0.3400 - val_loss: 0.9562 - val_accuracy: 0.2734

# %%
pwd

# %%
#from preprocessing import input_features_dict, target_features_dict, reverse_input_features_dict, reverse_target_features_dict, max_decoder_seq_length, input_docs, target_docs, input_tokens, target_tokens, max_encoder_seq_length
#from training_model import decoder_inputs, decoder_lstm, decoder_dense, encoder_input_data, num_decoder_tokens, num_encoder_tokens

#from tensorflow import keras
from keras.layers import Input, LSTM, Dense
from keras.models import Model, load_model
import numpy as np
import re

training_model = load_model('training_model.h5')
###### because we're working with a saved model
encoder_inputs = training_model.input[0]
encoder_outputs, state_h_enc, state_c_enc = training_model.layers[2].output
encoder_states = [state_h_enc, state_c_enc]
######
encoder_model = Model(encoder_inputs, encoder_states)

latent_dim = 256
decoder_state_input_hidden = Input(shape=(latent_dim,))
decoder_state_input_cell = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_hidden, decoder_state_input_cell]
decoder_outputs, state_hidden, state_cell = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_hidden, state_cell]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

# %%
def decode_sequence(test_input):
  # Encode the input as state vectors.
  states_value = encoder_model.predict(test_input)

  # Generate empty target sequence of length 1.
  target_seq = np.zeros((1, 1, num_decoder_tokens))
  # Populate the first token of target sequence with the start token.
  target_seq[0, 0, target_features_dict['<START>']] = 1.

  # Sampling loop for a batch of sequences
  # (to simplify, here we assume a batch of size 1).
  decoded_sentence = ''

  stop_condition = False
  while not stop_condition:
    # Run the decoder model to get possible 
    # output tokens (with probabilities) & states
    output_tokens, hidden_state, cell_state = decoder_model.predict(
      [target_seq] + states_value)

    # Choose token with highest probability
    sampled_token_index = np.argmax(output_tokens[0, -1, :])
    sampled_token = reverse_target_features_dict[sampled_token_index]
    decoded_sentence += " " + sampled_token

    # Exit condition: either hit max length
    # or find stop token.
    if (sampled_token == '<END>' or len(decoded_sentence) > max_decoder_seq_length):
      stop_condition = True

    # Update the target sequence (of length 1).
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0, 0, sampled_token_index] = 1.

    # Update states
    states_value = [hidden_state, cell_state]

  return decoded_sentence

# %%
class ChatBot:
  
  negative_responses = ("no", "nope", "nah", "naw", "not a chance", "sorry")

  exit_commands = ("quit", "pause", "exit", "goodbye", "bye", "later", "stop", 'end')
  
  def start_chat(self):
    user_response = input("Hi, I'm a chatbot trained on dialog from Seinfeld. Would you like to chat with me?\n")
    
    if user_response.lower() in self.negative_responses:
      print("Ok, have a great day!")
      return
    
    user_response = input('Great! I am still a work in progress. Try using a lot of different words when chatting with me. Ok, what do you want to talk about?')
    
    self.chat(user_response)
  
  def chat(self, reply):
    while not self.make_exit(reply):
      reply = input(self.generate_response(reply))
    
  # define .string_to_matrix() below:
  def string_to_matrix(self, user_input):
    tokens = re.findall(r"[\w']+|[^\s\w]", user_input)
    user_input_matrix = np.zeros(
      (1, max_encoder_seq_length, num_encoder_tokens),
      dtype='float32')
    for timestep, token in enumerate(tokens):
      # add an if clause to handle user input:
      if token in input_features_dict:
        user_input_matrix[0, timestep, input_features_dict[token]] = 1.
    return user_input_matrix
  
  def generate_response(self, user_input):
    input_matrix = self.string_to_matrix(user_input)
    states_value = encoder_model.predict(input_matrix)
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0, 0, target_features_dict['<START>']] = 1.
    
    chatbot_response = ''

    stop_condition = False
    while not stop_condition:
      output_tokens, hidden_state, cell_state = decoder_model.predict(
        [target_seq] + states_value)

      sampled_token_index = np.argmax(output_tokens[0, -1, :])
      sampled_token = reverse_target_features_dict[sampled_token_index]
      chatbot_response += " " + sampled_token
      
      if (sampled_token == '<END>' or len(chatbot_response) > max_decoder_seq_length):
        stop_condition = True
        
      target_seq = np.zeros((1, 1, num_decoder_tokens))
      target_seq[0, 0, sampled_token_index] = 1.
      
      if '<END>' in chatbot_response:
            chatbot_response = chatbot_response.replace('<END>', '')
            
      punctuations = [' ?', ' .', ' !', ' ,']            
      for punctuation in punctuations:
            if punctuation in chatbot_response:
                chatbot_response = chatbot_response.replace(punctuation, punctuation[-1])
      
      
      states_value = [hidden_state, cell_state]
      
    return chatbot_response
  
  def make_exit(self, reply):
    for exit_command in self.exit_commands:
      if exit_command in reply:
        print("Ok, have a great day!")
        return True
      
    return False

# %%
chat = ChatBot()

# %%
chat.start_chat()
# Out:
# Hi, I'm a chatbot trained on dialog from Seinfeld. Would you like to chat with me?
#  Yes
# Great! I am still a work in progress. Try using a lot of different words when chatting with me. Ok, what do you want to talk about?. What is that smell?
#  Will you stop it?  I thought you smelled it too?
#  So you have a good time.  This makes no sense
#  Well, maybe she should be my,.  Be your what?
#  I think I think so?  Definitely
#  Yeah.  stop
# Ok, have a great day!
